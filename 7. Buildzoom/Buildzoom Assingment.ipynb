# %% [markdown]
# This is an interview assignment I got from someone who interviewed at BuildZoom. The data and objective seemed nice, so I gave it a try.
#
# Objective:
# - Build a classifier that predicts whether a building permit's 'type' is 'ELECTRICAL' or not. Note that there are many different types of permits but we are only interested in 'ELECTRICAL'.

# %% [markdown]
# # Notebook setup

# %%
import numpy as np
import pandas as pd

# %%
 # Disable trunkating the middle of long dataframes. I want to see all the columns.
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# # Load data

# %%
train_data = pd.read_csv('./data/train_data.csv', sep='\t')
test_data = pd.read_csv('./data/xtest_data.csv', sep='\t')

# %%
train_data['is_electrical'] = train_data.type == 'ELECTRICAL'

# %%
train_data.head()
# Out:
#                                                                                            licensetype  \
# 0                                                                                                  NaN
# 1                                                                                                  NaN
# 2                                                                         SPECIALTY CONTRACTOR LICENSE
# 3  ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., GEN...
# 4                                                                                                  NaN
#
#            businessname legaldescription  \
# 0               ADT LLC              NaN
# 1                   NaN              NaN
# 2         KLN MEDIA LLC              NaN
# 3  OLSON ENERGY SERVICE              NaN
# 4                   NaN              NaN
#
#                                                                    description  \
# 0                                          INSTALL LOW VOLTAGE SECURITY SYSTEM
# 1                      INSTALL (1) NON-ILLUMINATED WALL SIGN - PLAZA GARIBALDI
# 2  INSTALL (1) NON-ILLUM ON-PREMISES WALL SIGN FOR &quot;PLAZA GARIBALDI&quot;
# 3                                       REPLACE OIL FURNACE W/ NEW GAS FURNACE
# 4                          WIRE NEW SINGLE FAMILY RESIDENCE W/ 200 AMP SERVICE
#
#              type                 subtype job_value  is_electrical
# 0      ELECTRICAL              COMMERCIAL       NaN           True
# 1  SIGN/BILLBOARD              COMMERCIAL       NaN          False
# 2  SIGN/BILLBOARD              COMMERCIAL       NaN          False
# 3    MECHANICAL /  SINGLE FAMILY / DUPLEX       NaN          False
# 4      ELECTRICAL  SINGLE FAMILY / DUPLEX       NaN           True

# %% [markdown]
# # EDA

# %%
import locale

# %% [markdown]
# ## Null values

# %%
train_data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100156 entries, 0 to 100155
# Data columns (total 8 columns):
# licensetype         36624 non-null object
# businessname        72575 non-null object
# legaldescription    24393 non-null object
# description         98842 non-null object
# type                87170 non-null object
# subtype             72604 non-null object
# job_value           15696 non-null object
# is_electrical       100156 non-null bool
# dtypes: bool(1), object(7)
# memory usage: 5.4+ MB

# %% [markdown]
# - The dataset contains quite a high number of null values.
# - There are even observations where each predictor is null. This offers no information so we can drop them.
# - job_value is being treated as an object, most likely because they have $ in them
# - Only one field is numerical, the others are all text, so we will most likely have to search for keywords in them.
# - We are tasked with predicting the type field, but there are about 13,000 observations that are missing this value. This is unlabelled data, so those can be dropped.

# %%
print("Before dropping NaN only: ", len(train_data))
nan_only = train_data[train_data.isnull().all(axis=1)]
train_data.drop(nan_only.index, inplace=True)
train_data.reset_index(drop=True, inplace=True)
print("After dropping NaN only: ", len(train_data))
# Out:
# Before dropping NaN only:  100156
# After dropping NaN only:  100156

# %%
test_data[test_data.isnull().all(axis=1)]
# Out:
#       licensetype businessname legaldescription description subtype job_value  \
# 21            NaN          NaN              NaN         NaN     NaN       NaN
# 67            NaN          NaN              NaN         NaN     NaN       NaN
# 15889         NaN          NaN              NaN         NaN     NaN       NaN
# 16058         NaN          NaN              NaN         NaN     NaN       NaN
# 16146         NaN          NaN              NaN         NaN     NaN       NaN
# 16186         NaN          NaN              NaN         NaN     NaN       NaN
# 16213         NaN          NaN              NaN         NaN     NaN       NaN
# 16263         NaN          NaN              NaN         NaN     NaN       NaN
#
#       electrical_only
# 21                NaN
# 67                NaN
# 88                NaN
# 103               NaN
# 463               NaN
# 508               NaN
# 509               NaN
# 530               NaN
# 741               NaN
# 742               NaN
# 744               NaN
# 822               NaN
# 903               NaN
# 939               NaN
# 1054              NaN
# 1055              NaN
# 1056              NaN
# 1078              NaN
# 1245              NaN
# 1286              NaN
# 1330              NaN
# 1395              NaN
# 1424              NaN
# 1437              NaN
# 1445              NaN
# 1502              NaN
# 1511              NaN
# 1664              NaN
# 1813              NaN
# 1835              NaN
# 1850              NaN
# 1980              NaN
# 2003              NaN
# 2048              NaN
# 2091              NaN
# 2152              NaN
# 2158              NaN
# 2225              NaN
# 2264              NaN
# 2284              NaN
# 2303              NaN
# 2307              NaN
# 2319              NaN
# 2344              NaN
# 2346              NaN
# 2425              NaN
# 2552              NaN
# 2672              NaN
# 2729              NaN
# 2799              NaN
# 2849              NaN
# 2868              NaN
# 2885              NaN
# 2899              NaN
# 2939              NaN
# 2977              NaN
# 3007              NaN
# 3070              NaN
# 3080              NaN
# 3110              NaN
# 3141              NaN
# 3155              NaN
# 3166              NaN
# 3190              NaN
# 3252              NaN
# 3321              NaN
# 3358              NaN
# 3398              NaN
# 3413              NaN
# 3415              NaN
# 3627              NaN
# 3640              NaN
# 3678              NaN
# 3817              NaN
# 3858              NaN
# 3913              NaN
# 4206              NaN
# 4277              NaN
# 4282              NaN
# 4342              NaN
# 4409              NaN
# 4566              NaN
# 4604              NaN
# 4620              NaN
# 4641              NaN
# 4642              NaN
# 4896              NaN
# 4901              NaN
# 5001              NaN
# 5227              NaN
# 5228              NaN
# 5284              NaN
# 5287              NaN
# 5298              NaN
# 5309              NaN
# 5489              NaN
# 5497              NaN
# 5518              NaN
# 5539              NaN
# 5540              NaN
# 5602              NaN
# 5603              NaN
# 5617              NaN
# 5703              NaN
# 5742              NaN
# 5894              NaN
# 5923              NaN
# 5943              NaN
# 6030              NaN
# 6091              NaN
# 6102              NaN
# 6166              NaN
# 6191              NaN
# 6223              NaN
# 6312              NaN
# 6466              NaN
# 6607              NaN
# 6645              NaN
# 6797              NaN
# 6826              NaN
# 6859              NaN
# 6902              NaN
# 6917              NaN
# 6986              NaN
# 7005              NaN
# 7131              NaN
# 7193              NaN
# 7194              NaN
# 7203              NaN
# 7204              NaN
# 7205              NaN
# 7319              NaN
# 7372              NaN
# 7375              NaN
# 7462              NaN
# 7585              NaN
# 7714              NaN
# 7738              NaN
# 7743              NaN
# 7821              NaN
# 7896              NaN
# 7928              NaN
# 7952              NaN
# 7999              NaN
# 8020              NaN
# 8053              NaN
# 8088              NaN
# 8105              NaN
# 8106              NaN
# 8179              NaN
# 8187              NaN
# 8195              NaN
# 8338              NaN
# 8368              NaN
# 8434              NaN
# 8443              NaN
# 8608              NaN
# 8678              NaN
# 8715              NaN
# 8739              NaN
# 8774              NaN
# 8826              NaN
# 8835              NaN
# 8855              NaN
# 8953              NaN
# 8960              NaN
# 8965              NaN
# 9010              NaN
# 9014              NaN
# 9082              NaN
# 9083              NaN
# 9099              NaN
# 9123              NaN
# 9138              NaN
# 9270              NaN
# 9295              NaN
# 9352              NaN
# 9437              NaN
# 9451              NaN
# 9524              NaN
# 9552              NaN
# 9575              NaN
# 9598              NaN
# 9671              NaN
# 9698              NaN
# 9745              NaN
# 9748              NaN
# 9763              NaN
# 9813              NaN
# 9900              NaN
# 9926              NaN
# 10090             NaN
# 10091             NaN
# 10093             NaN
# 10094             NaN
# 10118             NaN
# 10226             NaN
# 10285             NaN
# 10359             NaN
# 10374             NaN
# 10397             NaN
# 10434             NaN
# 10477             NaN
# 10495             NaN
# 10527             NaN
# 10636             NaN
# 10659             NaN
# 10664             NaN
# 10828             NaN
# 10833             NaN
# 10835             NaN
# 10848             NaN
# 10853             NaN
# 10938             NaN
# 10997             NaN
# 11075             NaN
# 11081             NaN
# 11183             NaN
# 11254             NaN
# 11255             NaN
# 11281             NaN
# 11282             NaN
# 11294             NaN
# 11320             NaN
# 11385             NaN
# 11386             NaN
# 11418             NaN
# 11419             NaN
# 11433             NaN
# 11487             NaN
# 11512             NaN
# 11591             NaN
# 11605             NaN
# 11758             NaN
# 11789             NaN
# 11795             NaN
# 11850             NaN
# 11851             NaN
# 11852             NaN
# 11853             NaN
# 11854             NaN
# 11855             NaN
# 11856             NaN
# 11857             NaN
# 12086             NaN
# 12087             NaN
# 12088             NaN
# 12097             NaN
# 12098             NaN
# 12099             NaN
# 12100             NaN
# 12101             NaN
# 12102             NaN
# 12103             NaN
# 12104             NaN
# 12352             NaN
# 12357             NaN
# 12358             NaN
# 12359             NaN
# 12360             NaN
# 12361             NaN
# 12362             NaN
# 12363             NaN
# 12364             NaN
# 12365             NaN
# 12366             NaN
# 12367             NaN
# 12368             NaN
# 12369             NaN
# 12370             NaN
# 12371             NaN
# 12372             NaN
# 12373             NaN
# 12374             NaN
# 12375             NaN
# 12376             NaN
# 12377             NaN
# 12378             NaN
# 12379             NaN
# 12458             NaN
# 12475             NaN
# 12566             NaN
# 12569             NaN
# 12729             NaN
# 12740             NaN
# 12875             NaN
# 12876             NaN
# 13023             NaN
# 13093             NaN
# 13278             NaN
# 13456             NaN
# 13683             NaN
# 13706             NaN
# 13858             NaN
# 13884             NaN
# 13933             NaN
# 14268             NaN
# 14292             NaN
# 14330             NaN
# 14340             NaN
# 14376             NaN
# 14384             NaN
# 14392             NaN
# 14408             NaN
# 14775             NaN
# 14786             NaN
# 15289             NaN
# 15307             NaN
# 15352             NaN
# 15353             NaN
# 15459             NaN
# 15461             NaN
# 15511             NaN
# 15518             NaN
# 15678             NaN
# 15700             NaN
# 15709             NaN
# 15759             NaN
# 15797             NaN
# 15831             NaN
# 15887             NaN
# 15889             NaN
# 16058             NaN
# 16146             NaN
# 16186             NaN
# 16213             NaN
# 16263             NaN

# %% [markdown]
# There are some objects which miss the "type" field, so it's unlabelled data. We can drop those.

# %%
unlabelled = train_data[train_data.type.isnull()]
train_data.drop(unlabelled.index, inplace=True)
train_data.reset_index(drop=True, inplace=True)
print("After dropping unlabelled data: ", len(train_data))
# Out:
# After dropping unlabelled data:  87170

# %%
train_data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87170 entries, 0 to 87169
# Data columns (total 8 columns):
# licensetype         36624 non-null object
# businessname        72573 non-null object
# legaldescription    24393 non-null object
# description         86924 non-null object
# type                87170 non-null object
# subtype             72604 non-null object
# job_value           15696 non-null object
# is_electrical       87170 non-null bool
# dtypes: bool(1), object(7)
# memory usage: 4.7+ MB

# %% [markdown]
# Description and business name have almost no null values, it will be important to use this feature.

# %% [markdown]
# ## Data types
#
# job_value should be numerical, but it's an object. Let's fix that.

# %%
job_values = train_data[train_data.job_value.notnull()].job_value
(job_values.str.startswith('$') & job_values.str.endswith('.00')).unique()
# Out:
# array([ True])

# %%
train_data.job_value = train_data.job_value.str.strip('$')
train_data.job_value = train_data.job_value.apply(lambda x: x[:-3] if pd.notnull(x) else x)

# %%
locale.setlocale(locale.LC_ALL, 'en_US.UTF8')
converted = train_data[train_data.job_value.notnull()].job_value.apply(locale.atoi)
train_data.loc[train_data.job_value.notnull(), 'job_value'] = converted
del converted

# %% [markdown]
# All job_value start with a $ and end with .00 so we can safely strip those.

# %% [markdown]
# # Feature Engineering
#
# Ideas:
# - Check which businesses do only electronic works
# - Explore similarities between business names that do electronic works, which words occur often
# - Explore description for similar words

# %% [markdown]
# ## Only electric contracts

# %%
only_electrical = train_data.groupby('businessname').is_electrical.agg(np.all)
only_electrical.name = 'electrical_only'
train_data = train_data.join(only_electrical, on='businessname')
test_data = test_data.join(only_electrical, on='businessname')

# %%
train_data.head()
# Out:
#                                                                                            licensetype  \
# 0                                                                                                  NaN
# 1                                                                                                  NaN
# 2                                                                         SPECIALTY CONTRACTOR LICENSE
# 3  ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., GEN...
# 4                                                                                                  NaN
#
#            businessname legaldescription  \
# 0               ADT LLC              NaN
# 1                   NaN              NaN
# 2         KLN MEDIA LLC              NaN
# 3  OLSON ENERGY SERVICE              NaN
# 4                   NaN              NaN
#
#                                                                    description  \
# 0                                          INSTALL LOW VOLTAGE SECURITY SYSTEM
# 1                      INSTALL (1) NON-ILLUMINATED WALL SIGN - PLAZA GARIBALDI
# 2  INSTALL (1) NON-ILLUM ON-PREMISES WALL SIGN FOR &quot;PLAZA GARIBALDI&quot;
# 3                                       REPLACE OIL FURNACE W/ NEW GAS FURNACE
# 4                          WIRE NEW SINGLE FAMILY RESIDENCE W/ 200 AMP SERVICE
#
#              type                 subtype job_value  is_electrical  \
# 0      ELECTRICAL              COMMERCIAL       NaN           True
# 1  SIGN/BILLBOARD              COMMERCIAL       NaN          False
# 2  SIGN/BILLBOARD              COMMERCIAL       NaN          False
# 3    MECHANICAL /  SINGLE FAMILY / DUPLEX       NaN          False
# 4      ELECTRICAL  SINGLE FAMILY / DUPLEX       NaN           True
#
#   electrical_only
# 0            True
# 1             NaN
# 2           False
# 3           False
# 4             NaN
