# %%
from ipywidgets import IntProgress
from IPython.display import display


#to avoid code duplication we import the previously defined functions
#note that this *runs* the whole module
# %run processFeatures.ipynb
# Out:
# [nltk_data] Downloading package punkt to /Users/zkovacs/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zkovacs/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
for filename in filenames:
    text = readFile(filename)
    print(filename)
    print("can borrow : " + canBorrow(text))
    print("min directors : " + str(findMinDirectors(text)))
    print("max directors : " + str(findMaxDirectors(text)))
    print("can directors borrow : " + canDirectorsBorrow(text))
    print("director resolution needed : " + resolutionNeeded(text))
    print("quorum : " + findQuorum(text))
    print("\n")
# Out:
# FINE SKILL HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# GENTLE SOAR LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# Polo Resources Limited.txt
# can borrow : yes
# min directors : 1
# max directors : 15
# can directors borrow : yes
# director resolution needed : yes
# quorum : two
#
#
# SKIPTON GLOBAL INVESTMENT LIMITED - BAD SCAN.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : no
# quorum : one half
#
#
# AGAPIER INVESTMENTS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# PLATFORM SPECIALTY PRODUCTS CORP.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : 2
#
#
# GOLDEN SAINT RESOURCES LTD.txt
# can borrow : yes
# min directors : 1
# max directors : 10
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# YuuZoo.txt
# can borrow : yes
# min directors : 2
# max directors : 2
# can directors borrow : no
# director resolution needed : no
# quorum : ten percent (10%)
#
#
# Pioneer Entertainment Group Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : 50%
#
#
# GLORY GENIUS INTERNATIONAL HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors :
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# Sable Mining Africa Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : no
# director resolution needed : no
# quorum : 2
#
#
# Atlas Mara Co-Nvest Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : no
# quorum : 2
#
#
# EQUATOR EXPLORATION LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# WELL PERFECTION LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# GRAND CONCORD INTERNATIONAL HOLDINGS LIMITED - BAD SCAN.txt
# can borrow : yes
# min directors : 2
# max directors : noMax
# can directors borrow : no
# director resolution needed : no
# quorum : 2
#
#
# CASH Retail Management (HK) Limited.txt
# can borrow : yes
# min directors : 2
# max directors : noMax
# can directors borrow : no
# director resolution needed : no
# quorum : 2
#
#
# MAS Real Estate Inc.txt
# can borrow : yes
# min directors : 4
# max directors : noMax
# can directors borrow : yes
# director resolution needed : no
# quorum : three shareholders holding in aggregate not less than twenty five per cent
#
#
# SHL Fashion Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# MORAL GLORY INTERNATIONAL LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# URU Metals Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# TALENT TREND HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# dolphin capital investors ltd.txt
# can borrow : yes
# min directors : 1
# max directors : 9
# can directors borrow : yes
# director resolution needed : no
# quorum : one half
#
#
# MYSQUAR LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# Euroasian Rail Skyway Systems Holding Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : 51%
#
#
# BILLION EXPO INTERNATIONAL LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors :
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# Wing Tai Properties Investment Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# SILVER STARLIGHT LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# MAX RICH GROUP LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# HIGH VALUE VENTURES LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# JIASEN INTERNATIONAL HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# Establishment Lab Holding.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : no
# director resolution needed : no
# quorum : 2
#
#
# ACHIEVE BLOOM LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# CHAMPSWORD LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# PHOENIX TIME HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# EUROPEAN METALS HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# ALIEN METALS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : 12
# can directors borrow : yes
# director resolution needed : yes
# quorum : 2
#
#
# THAURFIN LTD - BAD SCAN.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : 2
#
#
# CENTURY HERO INTERNATIONAL LIMITED - BAD SCAN.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# CMA INVESTMENT HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 2
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one third
#
#
# Falanx Group Limited.txt
# can borrow : yes
# min directors : 1
# max directors : 1914
# can directors borrow : yes
# director resolution needed : yes
# quorum : 2
#
#
# SAILFISH ROYALTY CORP.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : no
# director resolution needed : no
# quorum : one half
#
#
# PROSPER ONE ENTERPRISES LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors :
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# PICVILLE INVESTMENTS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# SOLAR STAR GLOBAL LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# Kalani Investments Limited.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# ReneSola Ltd.txt
# can borrow : yes
# min directors : 1
# max directors : 10
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half
#
#
# EVER MAPLE FLAVORS AND FRAGRANCES HOLDINGS LIMITED.txt
# can borrow : yes
# min directors : 1
# max directors : noMax
# can directors borrow : yes
# director resolution needed : yes
# quorum : one half

# %%
resultsPath = "../results/"
with open(resultsPath + "results_training.csv", "w") as text_file:
    text_file.write("companyName,canBorrow,minDirectors,maxDirectors,directorsBorrow,resolutionNeeded,quorum\n")
    progress = IntProgress(min=0, max=len(filenames)) # instantiate the progress bar
    display(progress) # display the progress bar
    for filename in filenames:
        text = readFile(filename)
        text_file.write("\"" + filename[:-4] + "\"" \
                       "," + canBorrow(text) + \
                       "," + str(findMinDirectors(text)) + \
                       "," + str(findMaxDirectors(text)) + \
                       "," + canDirectorsBorrow(text) + \
                       "," + resolutionNeeded(text) + \
                       "," + findQuorum(text) + "\n"
                       )
        progress.value += 1
# Out:
# IntProgress(value=0, max=47)
